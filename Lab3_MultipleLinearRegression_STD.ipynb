# %% [markdown]
# <a href="https://colab.research.google.com/github/toche7/mdsLab2/blob/main/Lab3_MultipleLinearRegression_STD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 3: Multiple Linear Regression

# %% [markdown]
# Version 001

# %% [markdown]
# ```
# from sklearn.linear_model import LinearRegression
# reg = LinearRegression()
# reg.fit(X, y)
# ```

# %% [markdown]
# | Method | Description |
# | ------------|------------ |
# | fit(X, y ) | Fit linear model. |
# | predict(X) | Predict using the linear model. |
# | score(X, y) | Return the coefficient of determination of the prediction.|

# %% [markdown]
# การสร้าง   Multiple Linear Regression จะใช้ library ในการสร้างโมเดลแบบเดียวกับการสร้าง simple linear regression model
# แบบ Hypothesis Model ของ Multiple Linear Regression สามารถแสดงได้ดังนี้
#
# $$
# \hat{y} = \theta_0 + \theta_1x_1 + \theta_2x_2 +...+\theta_nx_n \tag{1}
# $$

# %% [markdown]
# ## 1. Example MLR with Real Estate Data Set.

# %% [markdown]
# ### 1.1 Exploratory  Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# โหลดข้อมูลจากไฟล์ RealEstate.csv

# %%
#!wget https://raw.githubusercontent.com/toche7/DataSets/main/RealEstate.csv

# %%
df = pd.read_csv('https://github.com/toche7/DataSets/raw/main/RealEstate.csv')

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %% [markdown]
# ตรวจสอบข้อมูลด้วยคำสั่ง info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.columns = ['No', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'Y']

# %%
df.head()
# Out:
#    No        X1    X2         X3  X4        X5         X6     Y
# 0   1  2012.917  32.0   84.87882  10  24.98298  121.54024  37.9
# 1   2  2012.917  19.5  306.59470   9  24.98034  121.53951  42.2
# 2   3  2013.583  13.3  561.98450   5  24.98746  121.54391  47.3
# 3   4  2013.500  13.3  561.98450   5  24.98746  121.54391  54.8
# 4   5  2012.833   5.0  390.56840   5  24.97937  121.54245  43.1

# %% [markdown]
# เปลี่ยนชื่อ column ไปเป็น
#
# ['no','x1','x2','x3','x4','x5','x6','y']
#
# ให้ทำงานง่ายขี้น

# %% [markdown]
# ตรวจสอบค่า Correlation ของข้อมูล

# %%
df.corr()
# Out:
#           No        X1        X2        X3        X4        X5        X6  \
# No  1.000000 -0.048658 -0.032808 -0.013573 -0.012699 -0.010110 -0.011059
# X1 -0.048658  1.000000  0.017549  0.060880  0.009635  0.035058 -0.041082
# X2 -0.032808  0.017549  1.000000  0.025622  0.049593  0.054420 -0.048520
# X3 -0.013573  0.060880  0.025622  1.000000 -0.602519 -0.591067 -0.806317
# X4 -0.012699  0.009635  0.049593 -0.602519  1.000000  0.444143  0.449099
# X5 -0.010110  0.035058  0.054420 -0.591067  0.444143  1.000000  0.412924
# X6 -0.011059 -0.041082 -0.048520 -0.806317  0.449099  0.412924  1.000000
# Y  -0.028587  0.087491 -0.210567 -0.673613  0.571005  0.546307  0.523287
#
#            Y
# No -0.028587
# X1  0.087491
# X2 -0.210567
# X3 -0.673613
# X4  0.571005
# X5  0.546307
# X6  0.523287
# Y   1.000000

# %% [markdown]
# แสดงค่า correlation ด้วย heatmap

# %%
import seaborn as sns
sns.heatmap(df.corr(),cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# แสดงภาพความสัมพันธ์แบบ scatter martix

# %%
sns.pairplot(df)

# %%
X = df[['X1','X2','X3','X4', 'X5','X6']]

# %%
y = df[['Y']]

# %% [markdown]
# ### 1.2  Create Model Object and Training

# %%
from sklearn.linear_model import LinearRegression

# %%
mLR = LinearRegression()

# %%
mLR.fit(X,y)
# Out:
# LinearRegression()

# %%
mLR.score(X,y)
# Out:
# 0.5823704472723009

# %% [markdown]
# ### 1.3 Predition and Evaluation

# %% [markdown]
# Predict value of $\hat{y}$

# %% [markdown]
# Calculate the determination coefficient, $R^2$

# %% [markdown]
# Calculate the mean sequare error

# %%
# from sklearn.metrics import mean_squared_error
# prediction
# mse1 = mean_squared_error(y, predict)

# %% [markdown]
# ### 1.4 Select Feature for Model Development

# %% [markdown]
# ###  1.5 Data Standardization and Scaling

# %%
# from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#Xsc = sc.fit_transform(Xtrain)

# %%
X34 = df[['X1','X2']]

# %%
y = df[['Y']]

# %%
mLR.fit(X34,y)
mLR.score(X34,y)
# Out:
# 0.05265589225155287

# %% [markdown]
# model ตัวไหนมีประสิทธิภาพดีกว่ากัน ???
